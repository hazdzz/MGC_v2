# %%
import pandas as pd
import numpy as np

from plotnine import *
from plotnine.data import *
import matplotlib
import matplotlib.pyplot as plt
#matplotlib.rcParams['text.usetex'] = True

# %%
cornell_x = np.arange(195)
cornell_lap_y_1 = np.genfromtxt('cornell_sym_renorm_mag_lap_0_ev.csv', delimiter=',')
cornell_lap_y_2 = np.genfromtxt('cornell_sym_renorm_mag_lap_0.5_ev.csv', delimiter=',')
cornell_lap_y_3 = np.genfromtxt('cornell_sym_renorm_mag_lap_0.3333333333333333_ev.csv', delimiter=',')
cornell_lap_y_4 = np.genfromtxt('cornell_sym_renorm_mag_lap_0.25_ev.csv', delimiter=',')
cornell_lap_y_5 = np.genfromtxt('cornell_sym_renorm_mag_lap_0.2_ev.csv', delimiter=',')

# %%
plt.figure(dpi=120)

plt.plot(cornell_x, cornell_lap_y_1, color='red', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=0')
plt.plot(cornell_x, cornell_lap_y_2, color='royalblue', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/2')
plt.plot(cornell_x, cornell_lap_y_3, color='orange', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/3')
plt.plot(cornell_x, cornell_lap_y_4, color='gold', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/4')
plt.plot(cornell_x, cornell_lap_y_5, color='lawngreen', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/5')

#plt.title('Frequency response in Cornell')
plt.xlabel('Index')
plt.ylabel('Frequency response')
#plt.xlim(0, 2)
plt.ylim(0, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
plt.legend(loc='upper center', fontsize='small')
plt.savefig('FR_Cornell.png')
plt.show()

# %%
texas_x = np.arange(187)
texas_lap_y_1 = np.genfromtxt('texas_sym_renorm_mag_lap_0_ev.csv', delimiter=',')
texas_lap_y_2 = np.genfromtxt('texas_sym_renorm_mag_lap_0.5_ev.csv', delimiter=',')
texas_lap_y_3 = np.genfromtxt('texas_sym_renorm_mag_lap_0.3333333333333333_ev.csv', delimiter=',')
texas_lap_y_4 = np.genfromtxt('texas_sym_renorm_mag_lap_0.25_ev.csv', delimiter=',')

# %%
plt.figure(dpi=120)

plt.plot(texas_x, texas_lap_y_1, color='red', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=0')
plt.plot(texas_x, texas_lap_y_2, color='royalblue', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/2')
plt.plot(texas_x, texas_lap_y_3, color='orange', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/3')
plt.plot(texas_x, texas_lap_y_4, color='gold', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/4')

#plt.title('Frequency response in Texas')
plt.xlabel('Index')
plt.ylabel('Frequency response')
#plt.xlim(0, 2)
plt.ylim(0, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
plt.legend(loc='upper center', fontsize='small')
plt.savefig('FR_Texas.png')
plt.show()

# %%
washington_x = np.arange(230)
washington_lap_y_1 = np.genfromtxt('washington_sym_renorm_mag_lap_0_ev.csv', delimiter=',')
washington_lap_y_2 = np.genfromtxt('washington_sym_renorm_mag_lap_0.5_ev.csv', delimiter=',')
washington_lap_y_3 = np.genfromtxt('washington_sym_renorm_mag_lap_0.3333333333333333_ev.csv', delimiter=',')
washington_lap_y_4 = np.genfromtxt('washington_sym_renorm_mag_lap_0.25_ev.csv', delimiter=',')
washington_lap_y_5 = np.genfromtxt('washington_sym_renorm_mag_lap_0.2_ev.csv', delimiter=',')
washington_lap_y_6 = np.genfromtxt('washington_sym_renorm_mag_lap_0.16666666666666666_ev.csv', delimiter=',')

# %%
plt.figure(dpi=120)

plt.plot(washington_x, washington_lap_y_1, color='red', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=0')
plt.plot(washington_x, washington_lap_y_2, color='royalblue', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/2')
plt.plot(washington_x, washington_lap_y_3, color='orange', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/3')
plt.plot(washington_x, washington_lap_y_4, color='gold', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/4')
plt.plot(washington_x, washington_lap_y_5, color='lawngreen', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/5')
plt.plot(washington_x, washington_lap_y_6, color='aqua', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/6')

#plt.title('Frequency response in Washington')
plt.xlabel('Index')
plt.ylabel('Frequency response')
#plt.xlim(0, 2)
plt.ylim(0, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
plt.legend(loc='upper center', fontsize='small')
plt.savefig('FR_Washington.png')
plt.show()

# %%
wisconsin_x = np.arange(265)
wisconsin_lap_y_1 = np.genfromtxt('wisconsin_sym_renorm_mag_lap_0_ev.csv', delimiter=',')
wisconsin_lap_y_2 = np.genfromtxt('wisconsin_sym_renorm_mag_lap_0.5_ev.csv', delimiter=',')
wisconsin_lap_y_3 = np.genfromtxt('wisconsin_sym_renorm_mag_lap_0.3333333333333333_ev.csv', delimiter=',')
wisconsin_lap_y_4 = np.genfromtxt('wisconsin_sym_renorm_mag_lap_0.25_ev.csv', delimiter=',')
wisconsin_lap_y_5 = np.genfromtxt('wisconsin_sym_renorm_mag_lap_0.2_ev.csv', delimiter=',')
wisconsin_lap_y_6 = np.genfromtxt('wisconsin_sym_renorm_mag_lap_0.16666666666666666_ev.csv', delimiter=',')

# %%
plt.figure(dpi=120)

plt.plot(wisconsin_x, wisconsin_lap_y_1, color='red', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=0')
plt.plot(wisconsin_x, wisconsin_lap_y_2, color='royalblue', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/2')
plt.plot(wisconsin_x, wisconsin_lap_y_3, color='orange', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/3')
plt.plot(wisconsin_x, wisconsin_lap_y_4, color='gold', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/4')
plt.plot(wisconsin_x, wisconsin_lap_y_5, color='lawngreen', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/5')
plt.plot(wisconsin_x, wisconsin_lap_y_6, color='aqua', linewidth=2, linestyle="-", label=r'$\widetilde{\mathcal{L}}_{q}$ w/ q=1/6')

#plt.title('Frequency response in Wisconsin')
plt.xlabel('Index')
plt.ylabel('Frequency response')
#plt.xlim(0, 2)
plt.ylim(0, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
plt.legend(loc='upper center', fontsize='small')
plt.savefig('FR_Wisconsin.png')
plt.show()
